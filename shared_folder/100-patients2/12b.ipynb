# %%
#Add history from session 
#add a password
#deploy to streamlit cloud

# %%
#you input password into text/input box 
#this is sent securely encrypted to the sesrver
#the server takes your password and runs a hashing a;;gprothm and then checks the has against
#--what is stored in the database
#Main concept of a has is that it is a one way street

# %%
import bcrypt

password = b"firmflock95"
hashed_password = bcrypt.hashpw(password, bcrypt.gensalt())
print(hashed_password)
# Out:
# b'$2b$12$TsN8JOXUb33Vy8RBf7HJo.djsluLlPwHpDpoSeT4dGeEUeOHp4ngO'
